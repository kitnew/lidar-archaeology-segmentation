# %%
from PIL import Image
import numpy as np
from scipy.ndimage import uniform_filter

#preds_path = "../evaluation_results/full_prediction_map.npy"
#preds_path = "../experiments/0.80(5)_norm_shadow_resnet101(ImageNet1k_V2)_128(32)_BCE+DICE0.5_rednone_b16w16e50_l1e-4/DEM21_full_prediction_map.npy"
preds_path = "../experiments/0.80(5)_norm_shadow_resnet101_128(32)_BCE+DICE0.5_rednone_b16w16e50_l1e-4/DEM21_full_prediction_map.npy"
preds = np.load(preds_path)

smoothed = uniform_filter(preds, size=5)

# binarize
preds = (preds > 0.54).astype(np.uint8)

# save to uint8
img = (preds * 255).astype(np.uint8)

Image.fromarray(img).save("DEM21_opt_map.png")
